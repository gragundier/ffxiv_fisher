# %%
import tensorflow as tf
#import tensorflow_hub as hub
from google.protobuf import text_format
import numpy as np
import os
import time

gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
IMAGE_SHAPE=(224, 224)
BATCH_SIZE=32
NUM_CLASSES = 4

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255, 
    width_shift_range=.1,
    height_shift_range=.1,
    zoom_range=0.05,
    channel_shift_range=0.05,
    validation_split=0.025)
train_data = image_generator.flow_from_directory(
    "/home/gragundier/Data/ffxiv_fisher",
    target_size=IMAGE_SHAPE,
    subset="training",
    class_mode="categorical"
    )
validation_data = image_generator.flow_from_directory(
    "/home/gragundier/Data/ffxiv_fisher", 
    target_size=IMAGE_SHAPE,
    subset="validation",
    class_mode="categorical"
    )
# Out:
# Found 475 images belonging to 4 classes.
# Found 10 images belonging to 4 classes.

# %%
model = tf.keras.models.Sequential([
    # This is the first convolution
    tf.keras.layers.Conv2D(128, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.2),
    # The second convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    # The third convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    # The final convolution (same to make compute of reshape easier)
    tf.keras.layers.Conv2D(8, (3,3), padding='same', activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    #tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    
    # Reshape to fit into LSTM/GRU
    tf.keras.layers.Reshape((26*26,8)),
    tf.keras.layers.LSTM(8, activation='tanh', use_bias = True, recurrent_dropout=0),
    
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])

model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_80 (Conv2D)           (None, 222, 222, 128)     3584
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 111, 111, 128)     0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 111, 111, 128)     0
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 109, 109, 64)      73792
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 52, 52, 32)        18464
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 26, 26, 8)         2312
# _________________________________________________________________
# reshape_24 (Reshape)         (None, 676, 8)            0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 8)                 544
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 8)                 0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_24 (Dense)             (None, 512)               4608
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 105,356
# Trainable params: 105,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
copied_metrics = [
    tfma.metrics.ExampleCount(name='example_count'),
    tfma.metrics.WeightedExampleCount(name='weighted_example_count'),
    tf.keras.metrics.SparseCategoricalCrossentropy(
        name='sparse_categorical_crossentropy'),
    tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision', top_k=1),
    tf.keras.metrics.Precision(name='precision', top_k=3),
    tf.keras.metrics.Recall(name='recall', top_k=1),
    tf.keras.metrics.Recall(name='recall', top_k=3),
    tfma.metrics.MultiClassConfusionMatrixPlot(
        name='multi_class_confusion_matrix_plot'),
]
'''
#https://www.tensorflow.org/tfx/model_analysis/metrics
#metrics_specs = tfma.metrics.specs_from_metrics(metrics)

model.compile(loss = 'categorical_crossentropy', optimizer='sgd', metrics=['accuracy', 'FalsePositives'])

# %%
model_name = "sequential_22"
t = time.time()
log_dir = "/home/gragundier/Data/logs/{}".format("{}-{}".format(model_name, t))
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(train_data, epochs=500, validation_data = validation_data, callbacks=[tensorboard_callback], verbose = 1)
#history = model.fit(train_data, epochs=500, validation_data = validation_data, verbose = 1)
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# <ipython-input-92-dbbd89d3d9f8> in <module>
#       2 t = time.time()
#       3 log_dir = "/home/gragundier/Data/logs/{}".format("{}-{}".format(model_name, t))
# ----> 4 tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
#       5
#       6 history = model.fit(train_data, epochs=500, validation_data = validation_data, callbacks=[tensorboard_callback], verbose = 1)
#
# /usr/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in __init__(self, log_dir, histogram_freq, write_graph, write_images, update_freq, profile_batch, embeddings_freq, embeddings_metadata, **kwargs)
#    2067     self.embeddings_freq = embeddings_freq
#    2068     self.embeddings_metadata = embeddings_metadata
# -> 2069     self._init_profile_batch(profile_batch)
#    2070     self._epoch = 0
#    2071     self._global_train_batch = 0
#
# /usr/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in _init_profile_batch(self, profile_batch)
#    2280     if self._start_batch > 0:
#    2281       # Warm up and improve the profiling accuracy.
# -> 2282       profiler.start('')
#    2283       profiler.stop(save=False)
#    2284     # True when a trace is running.
#
# /usr/lib/python3.9/site-packages/tensorflow/python/profiler/profiler_v2.py in start(logdir, options)
#     113   with _profiler_lock:
#     114     if _profiler is not None:
# --> 115       raise errors.AlreadyExistsError(None, None,
#     116                                       'Another profiler is running.')
#     117     _profiler = _pywrap_profiler.ProfilerSession()
#
# AlreadyExistsError: Another profiler is running.

# %%
#t = time.time()

export_path = "/tmp/saved_models/{}".format(int(t))
model.save(export_path, save_format='tf')

export_path
# Out:
# INFO:tensorflow:Assets written to: /tmp/saved_models/1586918879/assets
# '/tmp/saved_models/1586918879'
